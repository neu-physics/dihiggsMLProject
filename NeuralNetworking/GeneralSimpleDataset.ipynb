# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
from network import Network
import torch

n_events = 1700
n_features = 12

# %%
# hh[:,0] = np.random.rand(n_events)
# hh[:,1] = np.random.rand(n_events)
# qcd[:, 0] = -1 * np.random.rand(n_events)
# qcd[:, 1] = -1 * np.random.rand(n_events)

hh = np.random.rand(n_events, n_features)
qcd = np.random.rand(n_events, n_features)


hh = np.abs(hh)
qcd = np.abs(qcd)

hh = hh * (1/np.max(hh))
qcd = -qcd * (1/np.max(qcd))

# add labels
hh_labels= np.zeros((len(hh),1))
hh_labels = hh_labels+1
hh_all = np.append(hh_all, hh_labels, axis=1)

hh_labels= np.zeros((len(hh),1))
hh_labels = hh_labels+1
hh_all = np.append(hh_all, hh_labels, axis=1)


print(hh[:4])
print(qcd[:4])
# Out:
# [[0.91249059 0.54587467 0.38310073 0.23789981 0.64823776 0.74855484
#   0.53390439 0.93322794 0.4846631  0.31831865 0.71559281 0.08509008]
#  [0.41201825 0.82615989 0.33739299 0.01966332 0.09560342 0.46986038
#   0.65185391 0.87826072 0.30753847 0.01431711 0.86305881 0.29671523]
#  [0.98359895 0.16471897 0.0289587  0.08302776 0.35628336 0.26247228
#   0.17096349 0.81545344 0.42696723 0.82477397 0.67752691 0.82967452]
#  [0.10404576 0.9382282  0.51412603 0.85988039 0.47153696 0.20374655
#   0.41696372 0.1422159  0.31959578 0.27685683 0.39520313 0.23250429]]
# [[-0.30256321 -0.1469369  -0.65072094 -0.58199395 -0.053813   -0.67729973
#   -0.73661461 -0.9542588  -0.78590327 -0.42956558 -0.45912814 -0.13672248]
#  [-0.03259751 -0.10133649 -0.97611431 -0.98278935 -0.28181469 -0.54090983
#   -0.58738043 -0.63396557 -0.10715439 -0.49759674 -0.03408133 -0.41909539]
#  [-0.78150658 -0.61381929 -0.45593138 -0.96213083 -0.60917363 -0.48724577
#   -0.77441608 -0.76646275 -0.04034598 -0.01045858 -0.01420678 -0.70665742]
#  [-0.29895541 -0.14468885 -0.40862248 -0.03877049 -0.79853444 -0.74441971
#   -0.62754192 -0.68307528 -0.81699017 -0.46945276 -0.05986372 -0.72650743]]

# %%
all_data = np.append(hh, qcd, axis=0)
print(all_data[:4])
for i in range(4):
    np.random.shuffle(all_data)
print(all_data[:4])
# Out:
# [[0.91249059 0.54587467 0.38310073 0.23789981 0.64823776 0.74855484
#   0.53390439 0.93322794 0.4846631  0.31831865 0.71559281 0.08509008]
#  [0.41201825 0.82615989 0.33739299 0.01966332 0.09560342 0.46986038
#   0.65185391 0.87826072 0.30753847 0.01431711 0.86305881 0.29671523]
#  [0.98359895 0.16471897 0.0289587  0.08302776 0.35628336 0.26247228
#   0.17096349 0.81545344 0.42696723 0.82477397 0.67752691 0.82967452]
#  [0.10404576 0.9382282  0.51412603 0.85988039 0.47153696 0.20374655
#   0.41696372 0.1422159  0.31959578 0.27685683 0.39520313 0.23250429]]
# [[-0.33611292 -0.08462883 -0.31651758 -0.7095864  -0.91840578 -0.72157772
#   -0.07302255 -0.10354069 -0.45100512 -0.69951983 -0.30568828 -0.11634162]
#  [-0.28353477 -0.12058506 -0.5934234  -0.45710531 -0.25467972 -0.21697932
#   -0.80214581 -0.19870926 -0.10930916 -0.04891072 -0.76134992 -0.89749585]
#  [-0.46927849 -0.74396294 -0.03194372 -0.91734293 -0.70038753 -0.86139466
#   -0.12210237 -0.6043439  -0.26351072 -0.50458315 -0.69984492 -0.11484408]
#  [-0.50951238 -0.18079053 -0.46168147 -0.986548   -0.9099983  -0.09858798
#   -0.95742829 -0.81737715 -0.55569206 -0.49262764 -0.93034308 -0.96192766]]
