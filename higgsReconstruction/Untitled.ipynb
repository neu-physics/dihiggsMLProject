# %%
from eventReconstructionClass import eventReconstruction

dihiggs_CMS_top4Tags = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_top4Tags.setConsiderFirstNjetsInPT(4)

dihiggs_CMS_top4Tags.runReconstruction()
dihiggs_CMS_top4Tags.makeEfficiencyPlots()
dihiggs_CMS_top4Tags.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.4
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  True
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...

# %%
dihiggs_CMS_dR03 = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_dR03.setConsiderFirstNjetsInPT(4)
dihiggs_CMS_dR03.setQuarkToJetCutDR(0.3)
dihiggs_CMS_dR03.runReconstruction()
dihiggs_CMS_dR03.makeEfficiencyPlots()
dihiggs_CMS_dR03.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.3
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  True
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...

# %%
dihiggs_CMS_dR02 = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_dR02.setConsiderFirstNjetsInPT(4)
dihiggs_CMS_dR02.setQuarkToJetCutDR(0.2)
dihiggs_CMS_dR02.runReconstruction()
dihiggs_CMS_dR02.makeEfficiencyPlots()
dihiggs_CMS_dR02.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.2
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  True
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...

# %%
dihiggs_CMS_dR05 = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_dR05.setConsiderFirstNjetsInPT(4)
dihiggs_CMS_dR05.setQuarkToJetCutDR(0.5)
dihiggs_CMS_dR05.runReconstruction()
dihiggs_CMS_dR05.makeEfficiencyPlots()
dihiggs_CMS_dR05.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.5
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  True
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...

# %%
dihiggs_CMS_dR06 = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_dR06.setConsiderFirstNjetsInPT(4)
dihiggs_CMS_dR06.setQuarkToJetCutDR(0.6)
dihiggs_CMS_dR06.runReconstruction()
dihiggs_CMS_dR06.makeEfficiencyPlots()
dihiggs_CMS_dR06.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.6
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  True
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...

# %%
from eventReconstructionClass import eventReconstruction
dihiggs_CMS_dR03 = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_dR03.setConsiderFirstNjetsInPT(4)
dihiggs_CMS_dR03.setQuarkToJetCutDR(0.3)
dihiggs_CMS_dR03.runReconstruction()
dihiggs_CMS_dR03.makeEfficiencyPlots()
dihiggs_CMS_dR03.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.3
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  True
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...

# %%
dihiggs_CMS_dR03.makeEfficiencyPlots()

# %%
from eventReconstructionClass import eventReconstruction
dihiggs_CMS_dR05 = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_dR05.setConsiderFirstNjetsInPT(4)
dihiggs_CMS_dR05.setQuarkToJetCutDR(0.5)
dihiggs_CMS_dR05.runReconstruction()
dihiggs_CMS_dR05.makeEfficiencyPlots()
dihiggs_CMS_dR05.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.5
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  True
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...

# %%
from eventReconstructionClass import eventReconstruction
dihiggs_CMS_dR05 = eventReconstruction('pp2hh4b_CMSPhaseII_0PU_top4Tags', '../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root', True)
dihiggs_CMS_dR05.setConsiderFirstNjetsInPT(4)
dihiggs_CMS_dR05.setQuarkToJetCutDR(0.5)
dihiggs_CMS_dR05.setRequireTags(False)
dihiggs_CMS_dR05.runReconstruction()
dihiggs_CMS_dR05.makeEfficiencyPlots()
dihiggs_CMS_dR05.printAllAlgorithmEventTotals(['Incl'])
# Out:
# =========   Options for pp2hh4b_CMSPhaseII_0PU_top4Tags  =========
# Transparency:  0.5
# N_Jets To Store:  4
# DeltaR Cut Between Jet and Quark:  0.5
# Higgs Mass:  125.0
# Higgs Width:  15.0
# Minimum Jet pT [GeV]:  20.0
# Maximum Jet |eta|:  2.5
# Algorithm saved for training:  equalDijetMass
# Higgs Width:  15.0
# Require only b-tagged jets:  False
# Order jets by pT:  True
# Consider first N jets in pT, N =  4
# ...
# Setting Delphes file;  ../../../MG5_aMC_v2_6_1/pp2hh4b_CMSPhaseII_0PU/Events/run_04_decayed_1/tag_1_delphes_events.root
# Finished loading branches...
# Analyzing event number 0
# Analyzing event number 2000
# Analyzing event number 4000
# Analyzing event number 6000
# Analyzing event number 8000
# Analyzing event number 10000
# Analyzing event number 12000
# Analyzing event number 14000
# Analyzing event number 16000
# Analyzing event number 18000
# Analyzing event number 20000
# Analyzing event number 22000
# Analyzing event number 24000
# Analyzing event number 26000
# ...
